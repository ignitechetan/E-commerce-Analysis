# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\monthly_spending_dataset_2020_2025.csv')
df
# Out:
#          Month  Groceries (₹)  Rent (₹)  Transportation (₹)  Gym (₹)  \
# 0   2020-01-01           4860     10000                2595      888
# 1   2020-02-01           6135     10000                2371      851
# 2   2020-03-01           6853     10000                2715     1143
# 3   2020-04-01           6904     10000                2582      869
# 4   2020-05-01           4562     10000                3028      830
# ..         ...            ...       ...                 ...      ...
# 64  2025-05-01           6850     13000                1643     1072
# 65  2025-06-01           7167     13000                2562      808
# 66  2025-07-01           7156     13000                2738      920
# 67  2025-08-01           8960     13000                2753      706
# 68  2025-09-01           8681     13000                3040      728
#
#     Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# 0            1520            1930             4311         4232
# ...

# %%
df.head()
# Out:
#         Month  Groceries (₹)  Rent (₹)  Transportation (₹)  Gym (₹)  \
# 0  2020-01-01           4860     10000                2595      888
# 1  2020-02-01           6135     10000                2371      851
# 2  2020-03-01           6853     10000                2715     1143
# 3  2020-04-01           6904     10000                2582      869
# 4  2020-05-01           4562     10000                3028      830
#
#    Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  EMI/Loans (₹)  \
# 0           1520            1930             4311         4232              0
# 1           1630            1923             5939         7329              0
# 2           1776            1185             4700         3625              0
# 3           1975            1274             4420         6426              0
# 4           1984            1631             4410         3647              0
#
#    Dining & Entertainment (₹)  Shopping & Wants (₹)  Total Expenditure (₹)  \
# ...

# %%
df.tail()
# Out:
#          Month  Groceries (₹)  Rent (₹)  Transportation (₹)  Gym (₹)  \
# 64  2025-05-01           6850     13000                1643     1072
# 65  2025-06-01           7167     13000                2562      808
# 66  2025-07-01           7156     13000                2738      920
# 67  2025-08-01           8960     13000                2753      706
# 68  2025-09-01           8681     13000                3040      728
#
#     Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# 64           1568            2890             8171         7761
# 65           2192            2068             6584         9916
# 66           1734            2686             8601        11756
# 67           1673            2776             6632        11659
# 68           1664            2717             8260        11924
#
#     EMI/Loans (₹)  Dining & Entertainment (₹)  Shopping & Wants (₹)  \
# 64              0                        1895                  2048
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Month                       69 non-null     object
#  1   Groceries (₹)               69 non-null     int64
#  2   Rent (₹)                    69 non-null     int64
#  3   Transportation (₹)          69 non-null     int64
#  4   Gym (₹)                     69 non-null     int64
#  5   Utilities (₹)               69 non-null     int64
#  6   Healthcare (₹)              69 non-null     int64
#  7   Investments (₹)             69 non-null     int64
#  8   Savings (₹)                 69 non-null     int64
#  9   EMI/Loans (₹)               69 non-null     int64
#  10  Dining & Entertainment (₹)  69 non-null     int64
#  11  Shopping & Wants (₹)        69 non-null     int64
#  12  Total Expenditure (₹)       69 non-null     int64
# ...

# %%
df.shape
# Out:
# (69, 14)

# %%
df.describe()
# Out:
#        Groceries (₹)     Rent (₹)  Transportation (₹)      Gym (₹)  \
# count      69.000000     69.00000           69.000000    69.000000
# mean     6286.913043  11000.00000         2569.260870   967.768116
# std      1233.330400   1424.57424          577.704373   149.508523
# min      4154.000000  10000.00000         1501.000000   700.000000
# 25%      5158.000000  10000.00000         2095.000000   851.000000
# 50%      6368.000000  10000.00000         2604.000000  1001.000000
# 75%      6931.000000  13000.00000         3035.000000  1084.000000
# max      8983.000000  13000.00000         3482.000000  1196.000000
#
#        Utilities (₹)  Healthcare (₹)  Investments (₹)   Savings (₹)  \
# count      69.000000       69.000000        69.000000     69.000000
# mean     1978.898551     1750.420290      6317.000000   7612.550725
# std       304.688228      577.078173      1459.367671   2257.266674
# min      1514.000000      837.000000      3952.000000   3625.000000
# ...

# %%
df.columns
# Out:
# Index(['Month', 'Groceries (₹)', 'Rent (₹)', 'Transportation (₹)', 'Gym (₹)',
#        'Utilities (₹)', 'Healthcare (₹)', 'Investments (₹)', 'Savings (₹)',
#        'EMI/Loans (₹)', 'Dining & Entertainment (₹)', 'Shopping & Wants (₹)',
#        'Total Expenditure (₹)', 'Income (₹)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Month                         object
# Groceries (₹)                  int64
# Rent (₹)                       int64
# Transportation (₹)             int64
# Gym (₹)                        int64
# Utilities (₹)                  int64
# Healthcare (₹)                 int64
# Investments (₹)                int64
# Savings (₹)                    int64
# EMI/Loans (₹)                  int64
# Dining & Entertainment (₹)     int64
# Shopping & Wants (₹)           int64
# Total Expenditure (₹)          int64
# Income (₹)                     int64
# dtype: object

# %%
df_drop=df.drop(columns=['EMI/Loans (₹)'])
df_drop
# Out:
#          Month  Groceries (₹)  Rent (₹)  Transportation (₹)  Gym (₹)  \
# 0   2020-01-01           4860     10000                2595      888
# 1   2020-02-01           6135     10000                2371      851
# 2   2020-03-01           6853     10000                2715     1143
# 3   2020-04-01           6904     10000                2582      869
# 4   2020-05-01           4562     10000                3028      830
# ..         ...            ...       ...                 ...      ...
# 64  2025-05-01           6850     13000                1643     1072
# 65  2025-06-01           7167     13000                2562      808
# 66  2025-07-01           7156     13000                2738      920
# 67  2025-08-01           8960     13000                2753      706
# 68  2025-09-01           8681     13000                3040      728
#
#     Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# 0            1520            1930             4311         4232
# ...

# %%
df.rename(columns={'Total Expenditure (₹)':'Monthly_Sales'})
# Out:
#          Month  Groceries (₹)  Rent (₹)  Transportation (₹)  Gym (₹)  \
# 0   2020-01-01           4860     10000                2595      888
# 1   2020-02-01           6135     10000                2371      851
# 2   2020-03-01           6853     10000                2715     1143
# 3   2020-04-01           6904     10000                2582      869
# 4   2020-05-01           4562     10000                3028      830
# ..         ...            ...       ...                 ...      ...
# 64  2025-05-01           6850     13000                1643     1072
# 65  2025-06-01           7167     13000                2562      808
# 66  2025-07-01           7156     13000                2738      920
# 67  2025-08-01           8960     13000                2753      706
# 68  2025-09-01           8681     13000                3040      728
#
#     Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# 0            1520            1930             4311         4232
# ...

# %%
df_sorted=df.sort_values(by='Month')
df_sorted
# Out:
#          Month  Groceries (₹)  Rent (₹)  Transportation (₹)  Gym (₹)  \
# 0   2020-01-01           4860     10000                2595      888
# 1   2020-02-01           6135     10000                2371      851
# 2   2020-03-01           6853     10000                2715     1143
# 3   2020-04-01           6904     10000                2582      869
# 4   2020-05-01           4562     10000                3028      830
# ..         ...            ...       ...                 ...      ...
# 64  2025-05-01           6850     13000                1643     1072
# 65  2025-06-01           7167     13000                2562      808
# 66  2025-07-01           7156     13000                2738      920
# 67  2025-08-01           8960     13000                2753      706
# 68  2025-09-01           8681     13000                3040      728
#
#     Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# 0            1520            1930             4311         4232
# ...

# %%
df_fillna=df.fillna(0)
df_fillna
# Out:
#          Month  Groceries (₹)  Rent (₹)  Transportation (₹)  Gym (₹)  \
# 0   2020-01-01           4860     10000                2595      888
# 1   2020-02-01           6135     10000                2371      851
# 2   2020-03-01           6853     10000                2715     1143
# 3   2020-04-01           6904     10000                2582      869
# 4   2020-05-01           4562     10000                3028      830
# ..         ...            ...       ...                 ...      ...
# 64  2025-05-01           6850     13000                1643     1072
# 65  2025-06-01           7167     13000                2562      808
# 66  2025-07-01           7156     13000                2738      920
# 67  2025-08-01           8960     13000                2753      706
# 68  2025-09-01           8681     13000                3040      728
#
#     Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# 0            1520            1930             4311         4232
# ...

# %%
df_unique=df.drop_duplicates()
df_unique
# Out:
#          Month  Groceries (₹)  Rent (₹)  Transportation (₹)  Gym (₹)  \
# 0   2020-01-01           4860     10000                2595      888
# 1   2020-02-01           6135     10000                2371      851
# 2   2020-03-01           6853     10000                2715     1143
# 3   2020-04-01           6904     10000                2582      869
# 4   2020-05-01           4562     10000                3028      830
# ..         ...            ...       ...                 ...      ...
# 64  2025-05-01           6850     13000                1643     1072
# 65  2025-06-01           7167     13000                2562      808
# 66  2025-07-01           7156     13000                2738      920
# 67  2025-08-01           8960     13000                2753      706
# 68  2025-09-01           8681     13000                3040      728
#
#     Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# 0            1520            1930             4311         4232
# ...

# %%
df_group1=df.groupby('Groceries (₹)').sum()
df_group1
# Out:
#                     Month  Rent (₹)  Transportation (₹)  Gym (₹)  \
# Groceries (₹)
# 4154           2023-06-01     10000                2909     1173
# 4378           2021-01-01     10000                2517      740
# 4379           2020-11-01     10000                2564      856
# 4502           2021-02-01     10000                3097      915
# 4537           2023-07-01     10000                1907      712
# ...                   ...       ...                 ...      ...
# 8652           2024-11-01     13000                3125     1117
# 8681           2025-09-01     13000                3040      728
# 8809           2024-07-01     13000                3131      956
# 8960           2025-08-01     13000                2753      706
# 8983           2023-12-01     13000                1768     1069
#
#                Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# Groceries (₹)
# 4154                    2284            1289             7147         7260
# ...

# %%
df_agggroup=df.groupby('Groceries (₹)').agg({'Transportation (₹)':'sum'})
df_agggroup
# Out:
#                Transportation (₹)
# Groceries (₹)
# 4154                         2909
# 4378                         2517
# 4379                         2564
# 4502                         3097
# 4537                         1907
# ...                           ...
# 8652                         3125
# 8681                         3040
# 8809                         3131
# 8960                         2753
# 8983                         1768
#
# [69 rows x 1 columns]

# %%
df_count=df.groupby('Groceries (₹)').count()
df_count
# Out:
#                Month  Rent (₹)  Transportation (₹)  Gym (₹)  Utilities (₹)  \
# Groceries (₹)
# 4154               1         1                   1        1              1
# 4378               1         1                   1        1              1
# 4379               1         1                   1        1              1
# 4502               1         1                   1        1              1
# 4537               1         1                   1        1              1
# ...              ...       ...                 ...      ...            ...
# 8652               1         1                   1        1              1
# 8681               1         1                   1        1              1
# 8809               1         1                   1        1              1
# 8960               1         1                   1        1              1
# 8983               1         1                   1        1              1
#
# ...

# %%
df_sum=df.groupby('Groceries (₹)').sum()
df_sum
# Out:
#                     Month  Rent (₹)  Transportation (₹)  Gym (₹)  \
# Groceries (₹)
# 4154           2023-06-01     10000                2909     1173
# 4378           2021-01-01     10000                2517      740
# 4379           2020-11-01     10000                2564      856
# 4502           2021-02-01     10000                3097      915
# 4537           2023-07-01     10000                1907      712
# ...                   ...       ...                 ...      ...
# 8652           2024-11-01     13000                3125     1117
# 8681           2025-09-01     13000                3040      728
# 8809           2024-07-01     13000                3131      956
# 8960           2025-08-01     13000                2753      706
# 8983           2023-12-01     13000                1768     1069
#
#                Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# Groceries (₹)
# 4154                    2284            1289             7147         7260
# ...

# %%
df_mean=df.groupby('Month').mean()
df_mean
# Out:
#             Groceries (₹)  Rent (₹)  Transportation (₹)  Gym (₹)  \
# Month
# 2020-01-01         4860.0   10000.0              2595.0    888.0
# 2020-02-01         6135.0   10000.0              2371.0    851.0
# 2020-03-01         6853.0   10000.0              2715.0   1143.0
# 2020-04-01         6904.0   10000.0              2582.0    869.0
# 2020-05-01         4562.0   10000.0              3028.0    830.0
# ...                   ...       ...                 ...      ...
# 2025-05-01         6850.0   13000.0              1643.0   1072.0
# 2025-06-01         7167.0   13000.0              2562.0    808.0
# 2025-07-01         7156.0   13000.0              2738.0    920.0
# 2025-08-01         8960.0   13000.0              2753.0    706.0
# 2025-09-01         8681.0   13000.0              3040.0    728.0
#
#             Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# Month
# 2020-01-01         1520.0          1930.0           4311.0       4232.0
# ...

# %%
df_max=df.groupby('Groceries (₹)').max()
df_max
# Out:
#                     Month  Rent (₹)  Transportation (₹)  Gym (₹)  \
# Groceries (₹)
# 4154           2023-06-01     10000                2909     1173
# 4378           2021-01-01     10000                2517      740
# 4379           2020-11-01     10000                2564      856
# 4502           2021-02-01     10000                3097      915
# 4537           2023-07-01     10000                1907      712
# ...                   ...       ...                 ...      ...
# 8652           2024-11-01     13000                3125     1117
# 8681           2025-09-01     13000                3040      728
# 8809           2024-07-01     13000                3131      956
# 8960           2025-08-01     13000                2753      706
# 8983           2023-12-01     13000                1768     1069
#
#                Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# Groceries (₹)
# 4154                    2284            1289             7147         7260
# ...

# %%
df_min=df.groupby('Groceries (₹)').min()
df_min
# Out:
#                     Month  Rent (₹)  Transportation (₹)  Gym (₹)  \
# Groceries (₹)
# 4154           2023-06-01     10000                2909     1173
# 4378           2021-01-01     10000                2517      740
# 4379           2020-11-01     10000                2564      856
# 4502           2021-02-01     10000                3097      915
# 4537           2023-07-01     10000                1907      712
# ...                   ...       ...                 ...      ...
# 8652           2024-11-01     13000                3125     1117
# 8681           2025-09-01     13000                3040      728
# 8809           2024-07-01     13000                3131      956
# 8960           2025-08-01     13000                2753      706
# 8983           2023-12-01     13000                1768     1069
#
#                Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# Groceries (₹)
# 4154                    2284            1289             7147         7260
# ...

# %%
df_dropna=df.dropna()
df_dropna
# Out:
#          Month  Groceries (₹)  Rent (₹)  Transportation (₹)  Gym (₹)  \
# 0   2020-01-01           4860     10000                2595      888
# 1   2020-02-01           6135     10000                2371      851
# 2   2020-03-01           6853     10000                2715     1143
# 3   2020-04-01           6904     10000                2582      869
# 4   2020-05-01           4562     10000                3028      830
# ..         ...            ...       ...                 ...      ...
# 64  2025-05-01           6850     13000                1643     1072
# 65  2025-06-01           7167     13000                2562      808
# 66  2025-07-01           7156     13000                2738      920
# 67  2025-08-01           8960     13000                2753      706
# 68  2025-09-01           8681     13000                3040      728
#
#     Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# 0            1520            1930             4311         4232
# ...

# %%
df_replace=df.replace({'NaN':0})
df_replace
# Out:
#          Month  Groceries (₹)  Rent (₹)  Transportation (₹)  Gym (₹)  \
# 0   2020-01-01           4860     10000                2595      888
# 1   2020-02-01           6135     10000                2371      851
# 2   2020-03-01           6853     10000                2715     1143
# 3   2020-04-01           6904     10000                2582      869
# 4   2020-05-01           4562     10000                3028      830
# ..         ...            ...       ...                 ...      ...
# 64  2025-05-01           6850     13000                1643     1072
# 65  2025-06-01           7167     13000                2562      808
# 66  2025-07-01           7156     13000                2738      920
# 67  2025-08-01           8960     13000                2753      706
# 68  2025-09-01           8681     13000                3040      728
#
#     Utilities (₹)  Healthcare (₹)  Investments (₹)  Savings (₹)  \
# 0            1520            1930             4311         4232
# ...

# %%
df_contain=df['Month'].str.contains('o')
df_contain
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 64    False
# 65    False
# 66    False
# 67    False
# 68    False
# Name: Month, Length: 69, dtype: bool

# %%
df_strip=df['Month'].str.strip()
df_strip
# Out:
# 0     2020-01-01
# 1     2020-02-01
# 2     2020-03-01
# 3     2020-04-01
# 4     2020-05-01
#          ...
# 64    2025-05-01
# 65    2025-06-01
# 66    2025-07-01
# 67    2025-08-01
# 68    2025-09-01
# Name: Month, Length: 69, dtype: object

# %%
counts = df['Month'].value_counts( )
counts
# Out:
# Month
# 2020-01-01    1
# 2020-02-01    1
# 2020-03-01    1
# 2020-04-01    1
# 2020-05-01    1
#              ..
# 2025-05-01    1
# 2025-06-01    1
# 2025-07-01    1
# 2025-08-01    1
# 2025-09-01    1
# Name: count, Length: 69, dtype: int64

# %%
numeral=df.select_dtypes(include=['number'])
corr=numeral.corr()
corr
# Out:
#                             Groceries (₹)  Rent (₹)  Transportation (₹)  \
# Groceries (₹)                    1.000000  0.690150            0.047389
# Rent (₹)                         0.690150  1.000000            0.002359
# Transportation (₹)               0.047389  0.002359            1.000000
# Gym (₹)                         -0.044392 -0.044259           -0.036850
# Utilities (₹)                   -0.041458  0.009995           -0.396178
# Healthcare (₹)                   0.476068  0.782886            0.080764
# Investments (₹)                  0.407920  0.702219           -0.029259
# Savings (₹)                      0.552062  0.649440           -0.017998
# EMI/Loans (₹)                    0.459364  0.681385            0.061368
# Dining & Entertainment (₹)       0.010600 -0.137801           -0.268389
# Shopping & Wants (₹)             0.152112  0.057996           -0.158445
# Total Expenditure (₹)            0.731629  0.907024            0.066440
# ...
